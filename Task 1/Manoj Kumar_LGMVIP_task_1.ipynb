# %% [markdown]
# # **Let's Grow More (LGMVIP) - "DATA SCIENCE INTERN"**
#
# **LGMVIP October-2023**

# %% [markdown]
# # MANOJ KUMAR K

# %% [markdown]
# **BEGINNER LEVEL TASK**
#
# **Task-1**
#
# **Iris Flowers Classification ML Project :**
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
#  Dataset Link:[https://archive.ics.uci.edu/dataset/53/iris](https://archive.ics.uci.edu/dataset/53/iris)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                names=["Sepal_Length_in_cm","Sepal_Width_in_cm","Petal_Length_in_cm","Petal_Width_in_cm","Flower_species"])

# %%
df
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm  Flower_species
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
df.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm Flower_species
# 0                0.2    Iris-setosa
# 1                0.2    Iris-setosa
# 2                0.2    Iris-setosa
# 3                0.2    Iris-setosa
# 4                0.2    Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['Sepal_Length_in_cm', 'Sepal_Width_in_cm', 'Petal_Length_in_cm',
#        'Petal_Width_in_cm', 'Flower_species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sepal_Length_in_cm  150 non-null    float64
#  1   Sepal_Width_in_cm   150 non-null    float64
#  2   Petal_Length_in_cm  150 non-null    float64
#  3   Petal_Width_in_cm   150 non-null    float64
#  4   Flower_species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# Sepal_Length_in_cm    0
# Sepal_Width_in_cm     0
# Petal_Length_in_cm    0
# Petal_Width_in_cm     0
# Flower_species        0
# dtype: int64

# %%
df['Flower_species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.describe()
# Out:
#        Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        Petal_Width_in_cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %% [markdown]
# # Visualise The Data

# %%
sns.pairplot(df,hue="Flower_species")

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
sns.scatterplot(x='Sepal_Length_in_cm',y='Petal_Length_in_cm',data=df,hue='Flower_species',ax=ax1)
sns.scatterplot(x='Sepal_Width_in_cm',y='Petal_Width_in_cm',data=df,hue='Flower_species',ax=ax2)
# Out:
# <Axes: xlabel='Sepal_Width_in_cm', ylabel='Petal_Width_in_cm'>

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
sns.boxplot(data=df,y='Sepal_Length_in_cm')
plt.subplot(1,4,2)
sns.boxplot(data=df,y='Sepal_Width_in_cm',color='green')
plt.subplot(1,4,3)
sns.boxplot(data=df,y='Petal_Width_in_cm',color='orange')
plt.subplot(1,4,4)
sns.boxplot(data=df,y='Petal_Width_in_cm',color='red')
# Out:
# <Axes: ylabel='Petal_Width_in_cm'>

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-15-c06bbf75caf3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True,cmap='coolwarm')

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c=(["Flower_species"])
df[c]=df[c].apply(le.fit_transform)
df.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm  Flower_species
# 0                0.2               0
# 1                0.2               0
# 2                0.2               0
# 3                0.2               0
# 4                0.2               0

# %% [markdown]
# # Split the Data

# %%
X = df.drop(columns=['Flower_species'])
Y = df['Flower_species']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X , Y , test_size = 0.3)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression(max_iter=1000)

# %%
#fit the model
lg.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predict on the test set
y_pred=lg.predict(x_test)
y_pred
# Out:
# array([1, 2, 0, 0, 1, 1, 0, 0, 0, 0, 0, 1, 1, 2, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 1, 0, 0, 2, 1, 1, 2, 0, 0, 0, 0, 1, 1, 1, 2, 2, 0, 2, 2,
#        2])

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_pred,y_test)
accuracy=accuracy_score(y_pred,y_test)
cr=classification_report(y_pred,y_test)
print("confusion_matrix:")
print(cm)
print("Accuracy:",accuracy)
print("Classification Report:")
print(cr)
# Out:
# confusion_matrix:
# [[18  0  0]
#  [ 0 11  3]
#  [ 0  0 13]]
# Accuracy: 0.9333333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      0.79      0.88        14
#            2       0.81      1.00      0.90        13
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.95      0.93      0.93        45

# %%
cm_display = ConfusionMatrixDisplay(cm,display_labels=['Iris-setosa','Iris-setosa','Iris-virginica'])
cm_display.plot()
plt.show()

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svn = SVC()
svn.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred1=svn.predict(x_test)
y_pred1
# Out:
# array([1, 2, 0, 0, 1, 1, 0, 0, 0, 0, 0, 1, 1, 2, 1, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 1, 0, 0, 2, 1, 1, 2, 0, 0, 0, 0, 1, 1, 1, 2, 2, 0, 2, 2,
#        2])

# %%
#from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_pred1,y_test)
accuracy=accuracy_score(y_pred1,y_test)
cr=classification_report(y_pred1,y_test)
print("confusion_matrix:")
print(cm)
print("Accuracy:",accuracy)
print("Classification Report:")
print(cr)
# Out:
# confusion_matrix:
# [[18  0  0]
#  [ 0 11  4]
#  [ 0  0 12]]
# Accuracy: 0.9111111111111111
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      0.73      0.85        15
#            2       0.75      1.00      0.86        12
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.91      0.90        45
# weighted avg       0.93      0.91      0.91        45

# %%
cm_display = ConfusionMatrixDisplay(cm,display_labels=['Iris-setosa','Iris-setosa','Iris-virginica'])
cm_display.plot()
plt.show()

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn import tree
classifier=tree.DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=svn.predict(x_test)
y_pred2
# Out:
# array([1, 2, 0, 0, 1, 1, 0, 0, 0, 0, 0, 1, 1, 2, 1, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 1, 0, 0, 2, 1, 1, 2, 0, 0, 0, 0, 1, 1, 1, 2, 2, 0, 2, 2,
#        2])

# %%
#from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_pred2,y_test)
accuracy=accuracy_score(y_pred2,y_test)
cr=classification_report(y_pred2,y_test)
print("confusion_matrix:")
print(cm)
print("Accuracy:",accuracy)
print("Classification Report:")
print(cr)
# Out:
# confusion_matrix:
# [[18  0  0]
#  [ 0 11  4]
#  [ 0  0 12]]
# Accuracy: 0.9111111111111111
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      0.73      0.85        15
#            2       0.75      1.00      0.86        12
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.91      0.90        45
# weighted avg       0.93      0.91      0.91        45

# %%
cm_display = ConfusionMatrixDisplay(cm,display_labels=['Iris-setosa','Iris-setosa','Iris-virginica'])
cm_display.plot()
plt.show()
